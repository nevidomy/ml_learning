# %%
import torch
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, NullFormatter
import time

DEVICE = "cuda"

def do_test(iterations, func, data):
    torch.cuda.synchronize()
    start = time.time()
    for _ in range(iterations):
        func(data)
    torch.cuda.synchronize()
    end = time.time()
    return end - start


def get_f(x, repeat):
    def f(x):
        for _ in range(repeat):
            x = x * 2 + 7
        return x
    return f

X = torch.randn((int(2**26),), device=DEVICE, dtype=torch.float16, requires_grad=False)

#f = get_f(X, 10)
#f = torch.jit.trace(f, X)
#state("before")
#with torch.jit.fuser("fuser2"):

#torch.cuda.synchronize()
#print(torch.jit.last_executed_optimized_graph())

#print(f"repeat={10} {do_test(10, f, X):.4}s")
    

repeats = []
times = []

mem_bend = []
flops_stats = []

def get_log_splits(start, end, n):
    return [int(start * (end/start)**(i/n)) for i in range(n+1)]

xes = get_log_splits(1, 512, 20)

for n in xes:
    print(f"\n-----------------------\nrepeat={n}:")
    f = get_f(X, n)
    f = torch.jit.trace(f,X)
    #f = torch.compile(f)
    for _ in range(5): f(X)
    #torch.cuda.synchronize()
    #print(torch.jit.last_executed_optimized_graph())
   
    M = 100

    data_size = X.numel() * X.element_size()
    t_iter = do_test(M, f, X)/M # time per iteration
    iter_per_sec = 1 / t_iter  # iterations per second
    memory_per_second = iter_per_sec * data_size * 2
    flops = 2 * n * X.numel() * iter_per_sec

    print(f"iter={M} t_per_iter={t_iter:.4}s {iter_per_sec:.2} iter/s {memory_per_second:.2} bytes/s")

    print(f"FLOPS: { flops/1e12:.2f} TF/s")
    print(f"Mem B/W: {memory_per_second/1e9:.2f} GB/s")
    
    repeats.append(n)
    times.append(t_iter*1000)
    mem_bend.append(memory_per_second/1e9)
    flops_stats.append(flops/1e12)

plt.plot(repeats, times, label="Time / iter")
plt.xlabel("fused(ops)")
plt.ylabel("Time (ms)") 
plt.legend()
plt.xscale("log", base=2)
ax = plt.gca()
ax.set_xticks(repeats)
ax.xaxis.set_major_formatter(ScalarFormatter())
ax.xaxis.set_minor_formatter(NullFormatter())
ax.ticklabel_format(axis="y", style="plain")
plt.show()

plt.plot(repeats, mem_bend, label="Mem B/W")
plt.xlabel("fused(ops)")
plt.ylabel("Mem B/W (GB/s)") 
plt.legend()
plt.xscale("log", base=2)
ax = plt.gca()
ax.set_xticks(repeats)
ax.xaxis.set_major_formatter(ScalarFormatter())
ax.xaxis.set_minor_formatter(NullFormatter())
ax.ticklabel_format(axis="y", style="plain")
plt.show()

plt.plot(repeats, flops_stats, label="FLOPS")
plt.xlabel("fused(ops)")
plt.ylabel("FLOPS (TF/s)") 
plt.legend()
plt.xscale("log", base=2)
ax = plt.gca()
ax.set_xticks(repeats)
ax.xaxis.set_major_formatter(ScalarFormatter())
ax.xaxis.set_minor_formatter(NullFormatter())
ax.ticklabel_format(axis="y", style="plain")
plt.show()



#print(torch.compile(get_f(X, 10)))
# Out:
# -----------------------
# repeat=1:
# iter=100 t_per_iter=0.001621s 6.2e+02 iter/s 3.3e+11 bytes/s
# FLOPS: 0.08 TF/s
# Mem B/W: 331.11 GB/s
#
# -----------------------
# repeat=1:
# iter=100 t_per_iter=0.001621s 6.2e+02 iter/s 3.3e+11 bytes/s
# FLOPS: 0.08 TF/s
# Mem B/W: 331.12 GB/s
#
# -----------------------
# repeat=1:
# iter=100 t_per_iter=0.001621s 6.2e+02 iter/s 3.3e+11 bytes/s
# FLOPS: 0.08 TF/s
# Mem B/W: 331.11 GB/s
#
# -----------------------
# repeat=2:
# iter=100 t_per_iter=0.001622s 6.2e+02 iter/s 3.3e+11 bytes/s
# FLOPS: 0.17 TF/s
# Mem B/W: 331.05 GB/s
#
# -----------------------
# repeat=3:
# iter=100 t_per_iter=0.001621s 6.2e+02 iter/s 3.3e+11 bytes/s
# FLOPS: 0.25 TF/s
# Mem B/W: 331.10 GB/s
#
# -----------------------
# repeat=4:
# iter=100 t_per_iter=0.001622s 6.2e+02 iter/s 3.3e+11 bytes/s
# FLOPS: 0.33 TF/s
# Mem B/W: 330.90 GB/s
#
# -----------------------
# repeat=6:
# iter=100 t_per_iter=0.001623s 6.2e+02 iter/s 3.3e+11 bytes/s
# FLOPS: 0.50 TF/s
# Mem B/W: 330.81 GB/s
#
# -----------------------
# repeat=8:
# iter=100 t_per_iter=0.001624s 6.2e+02 iter/s 3.3e+11 bytes/s
# FLOPS: 0.66 TF/s
# Mem B/W: 330.68 GB/s
#
# -----------------------
# repeat=12:
# iter=100 t_per_iter=0.001626s 6.2e+02 iter/s 3.3e+11 bytes/s
# FLOPS: 0.99 TF/s
# Mem B/W: 330.27 GB/s
#
# -----------------------
# repeat=16:
# iter=100 t_per_iter=0.001626s 6.1e+02 iter/s 3.3e+11 bytes/s
# FLOPS: 1.32 TF/s
# Mem B/W: 330.15 GB/s
#
# -----------------------
# repeat=22:
# iter=100 t_per_iter=0.001628s 6.1e+02 iter/s 3.3e+11 bytes/s
# FLOPS: 1.81 TF/s
# Mem B/W: 329.72 GB/s
#
# -----------------------
# repeat=30:
# iter=100 t_per_iter=0.001632s 6.1e+02 iter/s 3.3e+11 bytes/s
# FLOPS: 2.47 TF/s
# Mem B/W: 328.92 GB/s
#
# -----------------------
# repeat=42:
# iter=100 t_per_iter=0.001639s 6.1e+02 iter/s 3.3e+11 bytes/s
# FLOPS: 3.44 TF/s
# Mem B/W: 327.60 GB/s
#
# -----------------------
# repeat=57:
# iter=100 t_per_iter=0.001647s 6.1e+02 iter/s 3.3e+11 bytes/s
# FLOPS: 4.65 TF/s
# Mem B/W: 326.01 GB/s
#
# -----------------------
# repeat=78:
# iter=100 t_per_iter=0.001667s 6e+02 iter/s 3.2e+11 bytes/s
# FLOPS: 6.28 TF/s
# Mem B/W: 322.02 GB/s
#
# -----------------------
# repeat=107:
# iter=100 t_per_iter=0.001742s 5.7e+02 iter/s 3.1e+11 bytes/s
# FLOPS: 8.25 TF/s
# Mem B/W: 308.25 GB/s
#
# -----------------------
# repeat=147:
# iter=100 t_per_iter=0.002045s 4.9e+02 iter/s 2.6e+11 bytes/s
# FLOPS: 9.65 TF/s
# Mem B/W: 262.51 GB/s
#
# -----------------------
# repeat=200:
# iter=100 t_per_iter=0.002527s 4e+02 iter/s 2.1e+11 bytes/s
# FLOPS: 10.62 TF/s
# Mem B/W: 212.42 GB/s
#
# -----------------------
# repeat=274:
# iter=100 t_per_iter=0.003217s 3.1e+02 iter/s 1.7e+11 bytes/s
# FLOPS: 11.43 TF/s
# Mem B/W: 166.90 GB/s
#
# -----------------------
# repeat=374:
# iter=100 t_per_iter=0.005876s 1.7e+02 iter/s 9.1e+10 bytes/s
# FLOPS: 8.54 TF/s
# Mem B/W: 91.36 GB/s
#
# -----------------------
# repeat=512:
# iter=100 t_per_iter=0.005629s 1.8e+02 iter/s 9.5e+10 bytes/s
# FLOPS: 12.21 TF/s
# Mem B/W: 95.37 GB/s

# %% [markdown]
# So from what I see, I have on my RTX 3060 peaks:
#   - Mem B at around 320 GB/s
#   - Compute at ~6 TFLOPS
